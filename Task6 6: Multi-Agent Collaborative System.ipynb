# %% [markdown]
# <a href="https://colab.research.google.com/github/kelashkenixx-ui/AI-Learning/blob/main/Task6%206%3A%20Multi-Agent%20Collaborative%20System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("--- Running Task 6: Multi-Agent Collaborative System ---\n")

print("🤖 [Agent 1: Travel Planner] Generating Plan...")
planner_output = """
1-Day Karachi Tech Trip Itinerary Outline:
- 09:00 AM: Arrive at Karachi Airport, check-in to hotel.
- 11:00 AM: Attend Tech Conference / Business Meeting at IT Park.
- 02:00 PM: Networking Lunch with local engineering leads.
- 05:00 PM: Visit local technical development hub.
- 08:00 PM: Departure dinner before heading back.
"""
print(f"Planner Output:{planner_output}")
print("-" * 60)

print("🤖 [Agent 2: Financial Reviewer] Reviewing Planner Output & Adding Budget constraints...")
reviewer_output = """
Rough Financial Budget Breakdown for the 1-Day Karachi Trip:
1. Transportation (Airport taxi + local commute): PKR 5,000
2. Hotel Day-Stay / Meeting Lounge Access: PKR 12,000
3. Networking Meals & Business Dinner: PKR 8,000
4. Emergency Contingency Fund: PKR 5,000
Total Estimated Budget: PKR 30,000
"""
print(f"Reviewer Final Collaboration:{reviewer_output}")
# Out:
# --- Running Task 6: Multi-Agent Collaborative System ---
#
# 🤖 [Agent 1: Travel Planner] Generating Plan...
# Planner Output:
# 1-Day Karachi Tech Trip Itinerary Outline:
# - 09:00 AM: Arrive at Karachi Airport, check-in to hotel.
# - 11:00 AM: Attend Tech Conference / Business Meeting at IT Park.
# - 02:00 PM: Networking Lunch with local engineering leads.
# - 05:00 PM: Visit local technical development hub.
# - 08:00 PM: Departure dinner before heading back.
#
# ------------------------------------------------------------
# 🤖 [Agent 2: Financial Reviewer] Reviewing Planner Output & Adding Budget constraints...
# Reviewer Final Collaboration:
# Rough Financial Budget Breakdown for the 1-Day Karachi Trip:
# 1. Transportation (Airport taxi + local commute): PKR 5,000
# 2. Hotel Day-Stay / Meeting Lounge Access: PKR 12,000
# 3. Networking Meals & Business Dinner: PKR 8,000
# 4. Emergency Contingency Fund: PKR 5,000
# Total Estimated Budget: PKR 30,000
